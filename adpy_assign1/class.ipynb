# %%
print("Hello")
# Out:
# Hello

# %%
fruit='orange '
fruit*3
# Out:
# 'orange orange orange '

# %%
def addnum(a,b):
    return a+b

# %%
addnum(30,20)
# Out:
# 50

# %%
def mul(a,b):
    return a*b
print(mul(5,3))
# Out:
# 15

# %%
import math
math.sin(30)
# Out:
# -0.9880316240928618

# %%
bin(10)
# Out:
# '0b1010'

# %%
age = '10'
type(age)
# Out:
# str

# %%
int(age)
# Out:
# 10

# %%
type(age)
# Out:
# str

# %%
int(age)*3
# Out:
# 30

# %%
def helloname():
    name = input("what is your name\n")
    print("Hello", name)
# Out:
# Hello lok

# %%
helloname()
# Out:
# Hello anshu

# %%
# The name is included as parameter
def helloname(name):
    print("Hello", name)

helloname('Akhilesh') # Let us see what is the output
helloname(4)
# Out:
# Hello Akhilesh
# Hello 4
